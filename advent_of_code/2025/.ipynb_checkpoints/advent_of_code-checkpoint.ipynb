# %% [markdown]
# # Event of code 2025
# ## finish decorating the North Pole by December 12th

# %% [markdown]
# ### Day 1
# #### Secret Entrance
# A safe has a dial with only an arrow on it; around the dial are the numbers 0 through 99 in order. As you turn the dial, it makes a small click noise as it reaches each number.
# The puzzle input contains a sequence of rotations
# A rotation starts with an:
# L = toward lower numbers
# R = toward higher numbers
# Then, the rotation has a distance value
#
# The dial starts by pointing at 50
#
# The actual password is the number of times the dial is left pointing at 0 after any rotation in the sequence.

# %%
test_data = open("test_data.txt", "w")
day1 = open("day1.txt", "w")

# %%
# Out:
# Requirement already satisfied: pandas in /home/maartje/GitHub/fun_creations/funenv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/maartje/GitHub/fun_creations/funenv/lib/python3.12/site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/maartje/GitHub/fun_creations/funenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/maartje/GitHub/fun_creations/funenv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/maartje/GitHub/fun_creations/funenv/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/maartje/GitHub/fun_creations/funenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
